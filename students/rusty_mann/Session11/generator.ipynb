# %%
def y_range(start, stop, step=1):
    i = start
    while i < stop:
        yield i
        i += step

# %%
def intsum(i=0, stop=20):
    n=0
    while i < stop:
        current = i + n
        yield current
        i = current
        n += 1

# %%
def intsum(i=0):
    n=0
    while True:
        i += n
        yield i
        n += 1

# %%
gen = intsum()

# %%
next(gen)
next(gen)
next(gen)
#next(gen)
#next(gen)
# Out:
# 3

# %%
def double(i=1):
    yield i
    while True:
        i *= 2
        yield i

# %%
gen2 = intsum2()

# %%
next(gen2)
#next(gen2)
#next(gen2)
# Out:
# 8

# %%
def fib():
    a,b = 0,1
    while True:
        yield a
        b = a+b
        yield b
        a = a+b

# %%
genfib = fib()

# %%
next(genfib)
# Out:
# 8

# %%
def prime(i=3):
    for x in range(2, i+1):
        if i % x == 0:
            pass
        else:
            yield i
        i += 1

# %%
genprime = prime()

# %%
next(genprime)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-268-ff1e48859b24> in <module>()
# ----> 1 next(genprime)
#
# StopIteration:

# %%
def isprime():
    n=2
    yield n
    for x in range(2,n):
        if n%x == 0:
            continue
        #return True
        yield n
        n += 1

# %%
gen = isprime()

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-305-6e72e47198db> in <module>()
# ----> 1 next(gen)
#
# StopIteration:

# %%
def oprime(n):
    counter = 0
    b = 1
    if n == 1:
        print(2)
    while counter < n-1:
        b += 2
        for a in range(2,b):
            if b % a == 0:
                break
        else:
            counter = counter + 1
            if counter == n-1:
                print(b)

# %%
oprime(10)
# Out:
# 29

# %%
def prime():
    b = 1
    yield 2
    while True:
        b += 2
        for a in range(2,b):
            if b % a == 0:
                break
        else:
            yield b

# %%
gen = prime()

# %%
next(gen)
# Out:
# 29
