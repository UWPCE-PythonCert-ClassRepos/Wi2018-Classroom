# %%
import pandas as pd

# %%
music = pd.read_csv("featuresdf.csv")

# %%
music.head()
# Out:
#                       id                                name  \
# 0  7qiZfU4dY1lWllzX7mPBI                        Shape of You
# 1  5CtI0qwDJkDQGwXD1H1cL                   Despacito - Remix
# 2  4aWmUDTfIPGksMNLV2rQP  Despacito (Featuring Daddy Yankee)
# 3  6RUKPb4LETWmmr3iAEQkt            Something Just Like This
# 4  3DXncPQOG4VBw3QHh3S81                         I'm the One
#
#             artists  danceability  energy   key  loudness  mode  speechiness  \
# 0        Ed Sheeran         0.825   0.652   1.0    -3.183   0.0       0.0802
# 1        Luis Fonsi         0.694   0.815   2.0    -4.328   1.0       0.1200
# 2        Luis Fonsi         0.660   0.786   2.0    -4.757   1.0       0.1700
# 3  The Chainsmokers         0.617   0.635  11.0    -6.769   0.0       0.0317
# 4         DJ Khaled         0.609   0.668   7.0    -4.284   1.0       0.0367
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0        0.5810          0.000000    0.0931    0.931   95.977     233713.0
# 1        0.2290          0.000000    0.0924    0.813   88.931     228827.0
# 2        0.2090          0.000000    0.1120    0.846  177.833     228200.0
# 3        0.0498          0.000014    0.1640    0.446  103.019     247160.0
# 4        0.0552          0.000000    0.1670    0.811   80.924     288600.0
#
#    time_signature
# 0             4.0
# 1             4.0
# 2             4.0
# 3             4.0
# 4             4.0

# %%
music.describe()
# Out:
#        danceability      energy         key    loudness        mode  \
# count     100.00000  100.000000  100.000000  100.000000  100.000000
# mean        0.69682    0.660690    5.570000   -5.652650    0.580000
# std         0.12508    0.139207    3.731534    1.802067    0.496045
# min         0.25800    0.346000    0.000000  -11.462000    0.000000
# 25%         0.63500    0.556500    2.000000   -6.594500    0.000000
# 50%         0.71400    0.667500    6.000000   -5.437000    1.000000
# 75%         0.77025    0.787500    9.000000   -4.326750    1.000000
# max         0.92700    0.932000   11.000000   -2.396000    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   100.000000    100.000000        100.000000  100.000000  100.000000
# mean      0.103969      0.166306          0.004796    0.150607    0.517049
# std       0.095115      0.166730          0.026038    0.079011    0.216436
# min       0.023200      0.000259          0.000000    0.042400    0.086200
# 25%       0.043125      0.039100          0.000000    0.098275    0.375500
# 50%       0.062650      0.106500          0.000000    0.125000    0.502500
# 75%       0.123000      0.231250          0.000013    0.179250    0.679000
# max       0.431000      0.695000          0.210000    0.440000    0.966000
#
#             tempo   duration_ms  time_signature
# count  100.000000     100.00000          100.00
# mean   119.202460  218387.28000            3.99
# std     27.952928   32851.07772            0.10
# min     75.016000  165387.00000            3.00
# 25%     99.911750  198490.50000            4.00
# 50%    112.468000  214106.00000            4.00
# 75%    137.166000  230543.00000            4.00
# max    199.864000  343150.00000            4.00

# %%
[x for x in music.danceability if x >= 0.8]
# Out:
# [0.825,
#  0.904,
#  0.853,
#  0.833,
#  0.857,
#  0.809,
#  0.8690000000000001,
#  0.893,
#  0.852,
#  0.927,
#  0.927,
#  0.818,
#  0.8759999999999999,
#  0.841,
#  0.8320000000000001,
#  0.855,
#  0.884]

# %%
#[x for x in music.loudness if x < -5]

# %%
dance_vol = music[(music.danceability >= 0.8) & (music.loudness > -5)]

# %%
dance_vol
# Out:
#                        id                             name        artists  \
# 0   7qiZfU4dY1lWllzX7mPBI                     Shape of You     Ed Sheeran
# 8   0KKkJNfGyhkQ5aFogxQAP               That's What I Like     Bruno Mars
# 23  79cuOz3SPQTuFrp8WgftA  There's Nothing Holdin' Me Back   Shawn Mendes
# 42  5bcTCxgc7xVfSaMV3RuVk                            Feels  Calvin Harris
# 47  6mICuAdrwEjh6Y6lroV2K                         Chantaje        Shakira
# 59  6b8Be6ljOzmkOmFslEb23                        24K Magic     Bruno Mars
# 71  6gBFPUFcJLzWGx4lenP6h                       goosebumps   Travis Scott
# 91  4c2W3VKsOFoIg2SFaO6DY                        Your Song       Rita Ora
#
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0          0.825   0.652   1.0    -3.183   0.0       0.0802        0.5810
# 8          0.853   0.560   1.0    -4.961   1.0       0.0406        0.0130
# 23         0.857   0.800   2.0    -4.035   1.0       0.0583        0.3810
# 42         0.893   0.745  11.0    -3.105   0.0       0.0571        0.0642
# 47         0.852   0.773   8.0    -2.921   0.0       0.0776        0.1870
# 59         0.818   0.803   1.0    -4.282   1.0       0.0797        0.0340
# 71         0.841   0.728   7.0    -3.370   1.0       0.0484        0.0847
# 91         0.855   0.624   1.0    -4.093   1.0       0.0488        0.1580
#
#     instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.00000    0.0931    0.931   95.977     233713.0             4.0
# 8            0.00000    0.0944    0.860  134.066     206693.0             4.0
# 23           0.00000    0.0913    0.966  121.996     199440.0             4.0
# 42           0.00000    0.0943    0.872  101.018     223413.0             4.0
# 47           0.00003    0.1590    0.907  102.034     195840.0             4.0
# 59           0.00000    0.1530    0.632  106.970     225983.0             4.0
# 71           0.00000    0.1490    0.430  130.049     243837.0             4.0
# 91           0.00000    0.0513    0.962  117.959     180757.0             4.0

# %%
sorted_dance_vol = dance_vol.sort_values(by = ['danceability'], ascending=False)

# %%
sorted_dance_vol
# Out:
#                        id                             name        artists  \
# 42  5bcTCxgc7xVfSaMV3RuVk                            Feels  Calvin Harris
# 23  79cuOz3SPQTuFrp8WgftA  There's Nothing Holdin' Me Back   Shawn Mendes
# 91  4c2W3VKsOFoIg2SFaO6DY                        Your Song       Rita Ora
# 8   0KKkJNfGyhkQ5aFogxQAP               That's What I Like     Bruno Mars
# 47  6mICuAdrwEjh6Y6lroV2K                         Chantaje        Shakira
# 71  6gBFPUFcJLzWGx4lenP6h                       goosebumps   Travis Scott
# 0   7qiZfU4dY1lWllzX7mPBI                     Shape of You     Ed Sheeran
# 59  6b8Be6ljOzmkOmFslEb23                        24K Magic     Bruno Mars
#
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 42         0.893   0.745  11.0    -3.105   0.0       0.0571        0.0642
# 23         0.857   0.800   2.0    -4.035   1.0       0.0583        0.3810
# 91         0.855   0.624   1.0    -4.093   1.0       0.0488        0.1580
# 8          0.853   0.560   1.0    -4.961   1.0       0.0406        0.0130
# 47         0.852   0.773   8.0    -2.921   0.0       0.0776        0.1870
# 71         0.841   0.728   7.0    -3.370   1.0       0.0484        0.0847
# 0          0.825   0.652   1.0    -3.183   0.0       0.0802        0.5810
# 59         0.818   0.803   1.0    -4.282   1.0       0.0797        0.0340
#
#     instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 42           0.00000    0.0943    0.872  101.018     223413.0             4.0
# 23           0.00000    0.0913    0.966  121.996     199440.0             4.0
# 91           0.00000    0.0513    0.962  117.959     180757.0             4.0
# 8            0.00000    0.0944    0.860  134.066     206693.0             4.0
# 47           0.00003    0.1590    0.907  102.034     195840.0             4.0
# 71           0.00000    0.1490    0.430  130.049     243837.0             4.0
# 0            0.00000    0.0931    0.931   95.977     233713.0             4.0
# 59           0.00000    0.1530    0.632  106.970     225983.0             4.0

# %%
final_df = sorted_dance_vol[['artists', 'name', 'danceability', 'loudness']]
final_df
# Out:
#           artists                             name  danceability  loudness
# 42  Calvin Harris                            Feels         0.893    -3.105
# 23   Shawn Mendes  There's Nothing Holdin' Me Back         0.857    -4.035
# 91       Rita Ora                        Your Song         0.855    -4.093
# 8      Bruno Mars               That's What I Like         0.853    -4.961
# 47        Shakira                         Chantaje         0.852    -2.921
# 71   Travis Scott                       goosebumps         0.841    -3.370
# 0      Ed Sheeran                     Shape of You         0.825    -3.183
# 59     Bruno Mars                        24K Magic         0.818    -4.282

# %%
def dance_vol(df):
    good_music = []
    for artists, name, danceability, loudness in zip(music.artists, music.name, music.danceability, music.loudness):
        if danceability >= 0.8 and loudness > -5:
            line = (artists, name, danceability, loudness)  
            good_music.append(line)
    return good_music

# %%
all_good_music = dance_vol(music)
all_good_music
# Out:
# [('Ed Sheeran', 'Shape of You', 0.825, -3.1830000000000003),
#  ('Bruno Mars', "That's What I Like", 0.853, -4.961),
#  ('Shawn Mendes', "There's Nothing Holdin' Me Back", 0.857, -4.035),
#  ('Calvin Harris', 'Feels', 0.893, -3.105),
#  ('Shakira', 'Chantaje', 0.852, -2.9210000000000003),
#  ('Bruno Mars', '24K Magic', 0.818, -4.282),
#  ('Travis Scott', 'goosebumps', 0.841, -3.37),
#  ('Rita Ora', 'Your Song', 0.855, -4.093)]

# %%
sorted(all_good_music, key=lambda x: x[2], reverse=True)
# Out:
# [('Calvin Harris', 'Feels', 0.893, -3.105),
#  ('Shawn Mendes', "There's Nothing Holdin' Me Back", 0.857, -4.035),
#  ('Rita Ora', 'Your Song', 0.855, -4.093),
#  ('Bruno Mars', "That's What I Like", 0.853, -4.961),
#  ('Shakira', 'Chantaje', 0.852, -2.9210000000000003),
#  ('Travis Scott', 'goosebumps', 0.841, -3.37),
#  ('Ed Sheeran', 'Shape of You', 0.825, -3.1830000000000003),
#  ('Bruno Mars', '24K Magic', 0.818, -4.282)]

# %%
good_music = [(artists, name, danceability, loudness) for artists, name, danceability, loudness 
 in zip(music.artists, music.name, music.danceability, music.loudness) if danceability >= 0.8 and loudness > -5]

# %%
def sort_by_danceability(item):
    return item[2]
good_music.sort(key = sort_by_danceability, reverse=True)
good_music
#sorted_good_music = sorted(good_music, key=lambda x:x[2], reverse=True)
# Out:
# [('Calvin Harris', 'Feels', 0.893, -3.105),
#  ('Shawn Mendes', "There's Nothing Holdin' Me Back", 0.857, -4.035),
#  ('Rita Ora', 'Your Song', 0.855, -4.093),
#  ('Bruno Mars', "That's What I Like", 0.853, -4.961),
#  ('Shakira', 'Chantaje', 0.852, -2.9210000000000003),
#  ('Travis Scott', 'goosebumps', 0.841, -3.37),
#  ('Ed Sheeran', 'Shape of You', 0.825, -3.1830000000000003),
#  ('Bruno Mars', '24K Magic', 0.818, -4.282)]

# %%
music.describe().T
# Out:
#                   count           mean           std            min  \
# danceability      100.0       0.696820      0.125080       0.258000
# energy            100.0       0.660690      0.139207       0.346000
# key               100.0       5.570000      3.731534       0.000000
# loudness          100.0      -5.652650      1.802067     -11.462000
# mode              100.0       0.580000      0.496045       0.000000
# speechiness       100.0       0.103969      0.095115       0.023200
# acousticness      100.0       0.166306      0.166730       0.000259
# instrumentalness  100.0       0.004796      0.026038       0.000000
# liveness          100.0       0.150607      0.079011       0.042400
# valence           100.0       0.517049      0.216436       0.086200
# tempo             100.0     119.202460     27.952928      75.016000
# duration_ms       100.0  218387.280000  32851.077720  165387.000000
# time_signature    100.0       3.990000      0.100000       3.000000
#
#                             25%           50%            75%         max
# danceability           0.635000       0.71400       0.770250       0.927
# energy                 0.556500       0.66750       0.787500       0.932
# key                    2.000000       6.00000       9.000000      11.000
# loudness              -6.594500      -5.43700      -4.326750      -2.396
# mode                   0.000000       1.00000       1.000000       1.000
# speechiness            0.043125       0.06265       0.123000       0.431
# acousticness           0.039100       0.10650       0.231250       0.695
# instrumentalness       0.000000       0.00000       0.000013       0.210
# liveness               0.098275       0.12500       0.179250       0.440
# valence                0.375500       0.50250       0.679000       0.966
# tempo                 99.911750     112.46800     137.166000     199.864
# duration_ms       198490.500000  214106.00000  230543.000000  343150.000
# time_signature         4.000000       4.00000       4.000000       4.000

# %%
music.query('danceability > 0.8 and loudness <-5.0').sort_values(by = ['danceability'], ascending=True)
# Out:
#                        id                                 name  \
# 36  7hDc8b7IXETo14hHIHdnh                         Passionfruit
# 84  3QwBODjSEzelZyVjxPOHd            Otra Vez (feat. J Balvin)
# 14  0VgkVdmE4gld66l8iyGjg                             Mask Off
# 38  6EpRaXYhGOB3fj4V2uDkM                      Strip That Down
# 62  00lNx0OcTJrS3MKHcB80H       You Don't Know Me - Radio Edit
# 94  2fQrGHiQOvpL9UgPvtYy6                         Bank Account
# 5   7KXjTSCq5nL1LoYtL7XAw                              HUMBLE.
# 48  4Km5HrUvYTaSUfiSGPJeQ  Bad and Boujee (feat. Lil Uzi Vert)
# 51  343YBumqHu19cGoGARUTs                            Fake Love
#
#            artists  danceability  energy   key  loudness  mode  speechiness  \
# 36           Drake         0.809   0.463  11.0   -11.377   1.0       0.0396
# 84   Zion & Lennox         0.832   0.772  10.0    -5.429   1.0       0.1000
# 14          Future         0.833   0.434   2.0    -8.795   1.0       0.4310
# 38      Liam Payne         0.869   0.485   6.0    -5.595   1.0       0.0545
# 62       Jax Jones         0.876   0.669  11.0    -6.054   0.0       0.1380
# 94       21 Savage         0.884   0.346   8.0    -8.228   0.0       0.3510
# 5   Kendrick Lamar         0.904   0.611   1.0    -6.842   0.0       0.0888
# 48           Migos         0.927   0.665  11.0    -5.313   1.0       0.2440
# 51           Drake         0.927   0.488   9.0    -9.433   0.0       0.4200
#
#     acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 36      0.256000          0.085000    0.1090    0.364  111.980     298941.0
# 84      0.055900          0.000486    0.4400    0.704   96.016     209453.0
# 14      0.010200          0.021900    0.1650    0.281  150.062     204600.0
# 38      0.246000          0.000000    0.0765    0.527  106.028     204502.0
# 62      0.163000          0.000000    0.1850    0.682  124.007     213947.0
# 94      0.015100          0.000007    0.0871    0.376   75.016     220307.0
# 5       0.000259          0.000020    0.0976    0.400  150.020     177000.0
# 48      0.061000          0.000000    0.1230    0.175  127.076     343150.0
# 51      0.108000          0.000000    0.1960    0.605  133.987     210937.0
#
#     time_signature
# 36             4.0
# 84             4.0
# 14             4.0
# 38             4.0
# 62             4.0
# 94             4.0
# 5              4.0
# 48             4.0
# 51             4.0

# %%
#music
good_music = [(yield name, artists) for name, artists in zip(music.name, music.artists) if artists == "Ed Sheeran"]

# %%
next(good_music)
# Out:
# ('Shape of You', 'Ed Sheeran')

# %%
def high_energy():
    #favs = []
    line = None
    def find_high_energy(energy_level=0.8):
        nonlocal line
        for artists, name, energy in zip(music.artists, music.name, music.energy):
            if energy > energy_level:
                line = (artists, name, energy)
            return line
                #print(line)
                #favs.append(line)
                
    return find_high_energy

# %%
def high_energy():
    #favs = []
    def find_high_energy():
        songs = [(artists, name, energy) for artists, name, energy in zip(music.artists, music.name, music.energy) if energy > 0.8]
        return songs
        #favs.append(songs)
        #return favs
    return find_high_energy

# %%
high_energy_songs = high_energy()

# %%
high_energy_songs()
# Out:
# None
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Luis Fonsi', 'Despacito - Remix', 0.815)
# ('Post Malone', 'Congratulations', 0.812)
# ('Jason Derulo', 'Swalla (feat. Nicki Minaj & Ty Dolla $ign)', 0.8170000000000001)
# ('Ed Sheeran', 'Castle on the Hill', 0.8340000000000001)
# ('Ed Sheeran', 'Castle on the Hill', 0.8340000000000001)
# ('Ed Sheeran', 'Castle on the Hill', 0.8340000000000001)
# ('Ed Sheeran', 'Castle on the Hill', 0.8340000000000001)
# ('Imagine Dragons', 'Thunder', 0.81)
# ('Imagine Dragons', 'Thunder', 0.81)
# ('Imagine Dragons', 'Thunder', 0.81)
# ('Danny Ocean', 'Me Rehúso', 0.804)
# ('Danny Ocean', 'Me Rehúso', 0.804)
# ('Ed Sheeran', 'Galway Girl', 0.8759999999999999)
# ('Ed Sheeran', 'Galway Girl', 0.8759999999999999)
# ('Ed Sheeran', 'Galway Girl', 0.8759999999999999)
# ('Ed Sheeran', 'Galway Girl', 0.8759999999999999)
# ('The Weeknd', 'I Feel It Coming', 0.813)
# ('The Weeknd', 'I Feel It Coming', 0.813)
# ('The Weeknd', 'I Feel It Coming', 0.813)
# ('The Weeknd', 'I Feel It Coming', 0.813)
# ('The Weeknd', 'I Feel It Coming', 0.813)
# ('The Weeknd', 'I Feel It Coming', 0.813)
# ('The Weeknd', 'I Feel It Coming', 0.813)
# ('The Weeknd', 'I Feel It Coming', 0.813)
# ('The Weeknd', 'I Feel It Coming', 0.813)
# ('The Weeknd', 'I Feel It Coming', 0.813)
# ('The Weeknd', 'I Feel It Coming', 0.813)
# ('Starley', 'Call On Me - Ryan Riback Extended Remix', 0.843)
# ('Starley', 'Call On Me - Ryan Riback Extended Remix', 0.843)
# ('Starley', 'Call On Me - Ryan Riback Extended Remix', 0.843)
# ('Starley', 'Call On Me - Ryan Riback Extended Remix', 0.843)
# ('Starley', 'Call On Me - Ryan Riback Extended Remix', 0.843)
# ('Starley', 'Call On Me - Ryan Riback Extended Remix', 0.843)
# ('Starley', 'Call On Me - Ryan Riback Extended Remix', 0.843)
# ('Starley', 'Call On Me - Ryan Riback Extended Remix', 0.843)
# ('Starley', 'Call On Me - Ryan Riback Extended Remix', 0.843)
# ('Martin Jensen', 'Solo Dance', 0.836)
# ('Martin Jensen', 'Solo Dance', 0.836)
# ('Martin Jensen', 'Solo Dance', 0.836)
# ('Martin Jensen', 'Solo Dance', 0.836)
# ('Martin Jensen', 'Solo Dance', 0.836)
# ('Enrique Iglesias', 'SUBEME LA RADIO', 0.823)
# ('Maggie Lindemann', 'Pretty Girl - Cheat Codes X CADE Remix', 0.868)
# ('Maggie Lindemann', 'Pretty Girl - Cheat Codes X CADE Remix', 0.868)
# ('Maggie Lindemann', 'Pretty Girl - Cheat Codes X CADE Remix', 0.868)
# ('Bruno Mars', '24K Magic', 0.8029999999999999)
# ('Bruno Mars', '24K Magic', 0.8029999999999999)
# ('Bruno Mars', '24K Magic', 0.8029999999999999)
# ('Bruno Mars', '24K Magic', 0.8029999999999999)
# ('Katy Perry', 'Chained To The Rhythm', 0.8009999999999999)
# ('Katy Perry', 'Chained To The Rhythm', 0.8009999999999999)
# ('Katy Perry', 'Chained To The Rhythm', 0.8009999999999999)
# ('Katy Perry', 'Chained To The Rhythm', 0.8009999999999999)
# ('Katy Perry', 'Chained To The Rhythm', 0.8009999999999999)
# ('Wisin', 'Escápate Conmigo', 0.8640000000000001)
# ('Wisin', 'Escápate Conmigo', 0.8640000000000001)
# ('Wisin', 'Escápate Conmigo', 0.8640000000000001)
# ('Wisin', 'Escápate Conmigo', 0.8640000000000001)
# ('Wisin', 'Escápate Conmigo', 0.8640000000000001)
# ('Wisin', 'Escápate Conmigo', 0.8640000000000001)
# ('Wisin', 'Escápate Conmigo', 0.8640000000000001)
# ('Wisin', 'Escápate Conmigo', 0.8640000000000001)
# ('Wisin', 'Escápate Conmigo', 0.8640000000000001)
# ('Steve Aoki', 'Just Hold On', 0.932)
# ('Steve Aoki', 'Just Hold On', 0.932)
# ('Steve Aoki', 'Just Hold On', 0.932)
# ('Steve Aoki', 'Just Hold On', 0.932)
# ('CNCO', 'Reggaetón Lento (Bailemos)', 0.838)
# ('CNCO', 'Reggaetón Lento (Bailemos)', 0.838)
# ('CNCO', 'Reggaetón Lento (Bailemos)', 0.838)
# ('CNCO', 'Reggaetón Lento (Bailemos)', 0.838)
# ('CNCO', 'Reggaetón Lento (Bailemos)', 0.838)
# ('CNCO', 'Reggaetón Lento (Bailemos)', 0.838)
# ('CNCO', 'Reggaetón Lento (Bailemos)', 0.838)
# ('CNCO', 'Reggaetón Lento (Bailemos)', 0.838)
# ('The Vamps', 'All Night', 0.809)
# ('The Vamps', 'All Night', 0.809)
# ('The Vamps', 'All Night', 0.809)
# ('The Vamps', 'All Night', 0.809)
# ('The Vamps', 'All Night', 0.809)
# ('The Vamps', 'All Night', 0.809)
# ('The Vamps', 'All Night', 0.809)
# ('The Chainsmokers', "Don't Let Me Down", 0.8590000000000001)
# ('The Chainsmokers', "Don't Let Me Down", 0.8590000000000001)
# ('The Chainsmokers', "Don't Let Me Down", 0.8590000000000001)
# ('The Chainsmokers', "Don't Let Me Down", 0.8590000000000001)

# %%
high_energy_songs(0.7)
